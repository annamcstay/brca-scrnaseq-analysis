# %%
import os
import pandas as pd

# Set working directory
os.chdir(r"C:\Users\annam\OneDrive\Dissertation")

# Check working directory
print("Current working directory:")
print(os.getcwd())

# List files in main folder
print("\nFiles in folder:")
print(os.listdir())

# List files inside extracted GEO folder
print("\nFiles inside extracted folder:")
print(os.listdir("GSE114725_rna_raw.csv"))

# Load the dataset
df = pd.read_csv("GSE114725_rna_raw.csv/raw_corrected.csv", index_col=0)

# Check shape
print("\nDataframe shape:")
print(df.shape)

# Preview data
df.head()
# Out:
# Current working directory:
# C:\Users\annam\OneDrive\Dissertation
#
# Files in folder:
# ['Dataset mining.xlsx', 'Dissertation', 'Gold standard tutorial.pdf', 'GSE114725_rna_raw.csv', 'GSE114725_rna_raw.csv.gz', 'Hallmarks of cancer Hanahan 20222.pdf', 'Lit Review and Intro foundation.docx', 'Lit Review and Intro foundation.pdf', 'Macrophages.pdf', 'ScSeq in cancer research Lei et al.pdf', 'Understanding the TIME.pdf']
#
# Files inside extracted folder:
# ['raw_corrected.csv']
