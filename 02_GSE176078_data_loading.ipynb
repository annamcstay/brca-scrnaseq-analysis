# %%
import scanpy as sc
import pandas as pd
import os

# %%
# Set correct path
base_path = r"C:\Users\annam\Downloads\GSE176078_Wu_etal_2021_BRCA_scRNASeq\Wu_etal_2021_BRCA_scRNASeq"

# %%
# Check files
print(os.listdir(base_path))
# Out:
# ['count_matrix_barcodes.tsv', 'count_matrix_genes.tsv', 'count_matrix_sparse.mtx', 'metadata.csv']

# %%
# 1. Load matrix
adata = sc.read_mtx(base_path + r"\count_matrix_sparse.mtx")

# %%
# Load genes and barcodes
genes = pd.read_csv(base_path + r"\count_matrix_genes.tsv", header=None, sep="\t")
barcodes = pd.read_csv(base_path + r"\count_matrix_barcodes.tsv", header=None, sep="\t")

# %%
# Since matrix is genes x cells:
adata.obs_names = genes[0].astype(str)
adata.var_names = barcodes[0].astype(str)

# %%
# Transpose to cells x genes
adata = adata.T

# %%
# Now check
print(adata)
print(adata.obs_names[:5])
print(adata.var_names[:5])
# Out:
# AnnData object with n_obs × n_vars = 100064 × 29733
# Index(['CID3586_AAGACCTCAGCATGAG', 'CID3586_AAGGTTCGTAGTACCT',
#        'CID3586_ACCAGTAGTTGTGGCC', 'CID3586_ACCCACTAGATGTCGG',
#        'CID3586_ACTGATGGTCAACTGT'],
#       dtype='object')
# Index(['RP11-34P13.7', 'FO538757.3', 'FO538757.2', 'AP006222.2',
#        'RP4-669L17.10'],
#       dtype='object')

# %%
meta = pd.read_csv(base_path + r"\metadata.csv")

print(meta.columns)
meta.head()
# Out:
# Index(['Unnamed: 0', 'orig.ident', 'nCount_RNA', 'nFeature_RNA',
#        'percent.mito', 'subtype', 'celltype_subset', 'celltype_minor',
#        'celltype_major'],
#       dtype='object')
#                  Unnamed: 0 orig.ident  nCount_RNA  nFeature_RNA  \
# 0  CID3586_AAGACCTCAGCATGAG    CID3586        4581          1689
# 1  CID3586_AAGGTTCGTAGTACCT    CID3586        1726           779
# 2  CID3586_ACCAGTAGTTGTGGCC    CID3586        1229           514
# 3  CID3586_ACCCACTAGATGTCGG    CID3586        1352           609
# 4  CID3586_ACTGATGGTCAACTGT    CID3586        1711           807
#
#    percent.mito subtype    celltype_subset     celltype_minor celltype_major
# 0      1.506221   HER2+  Endothelial ACKR1  Endothelial ACKR1    Endothelial
# 1      5.793743   HER2+  Endothelial ACKR1  Endothelial ACKR1    Endothelial
# 2      1.383238   HER2+  Endothelial ACKR1  Endothelial ACKR1    Endothelial
# 3      1.923077   HER2+  Endothelial ACKR1  Endothelial ACKR1    Endothelial
# ...

# %%
# Set correct index
meta.index = meta["Unnamed: 0"].astype(str)

# Align metadata to AnnData
adata.obs = meta.loc[adata.obs_names]

# %%
# Add dataset label
adata.obs["dataset"] = "GSE176078"

# Clean names
adata.var_names_make_unique()
adata.obs_names_make_unique()

# Save
adata.write(r"C:\Users\annam\Dissertation 2026\GSE176078_raw.h5ad")

# Final check
print(adata)
adata.obs.head()
# Out:
# AnnData object with n_obs × n_vars = 100064 × 29733
#     obs: 'Unnamed: 0', 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mito', 'subtype', 'celltype_subset', 'celltype_minor', 'celltype_major', 'dataset'
#                                         Unnamed: 0 orig.ident  nCount_RNA  \
# CID3586_AAGACCTCAGCATGAG  CID3586_AAGACCTCAGCATGAG    CID3586        4581
# CID3586_AAGGTTCGTAGTACCT  CID3586_AAGGTTCGTAGTACCT    CID3586        1726
# CID3586_ACCAGTAGTTGTGGCC  CID3586_ACCAGTAGTTGTGGCC    CID3586        1229
# CID3586_ACCCACTAGATGTCGG  CID3586_ACCCACTAGATGTCGG    CID3586        1352
# CID3586_ACTGATGGTCAACTGT  CID3586_ACTGATGGTCAACTGT    CID3586        1711
#
#                           nFeature_RNA  percent.mito subtype  \
# CID3586_AAGACCTCAGCATGAG          1689      1.506221   HER2+
# CID3586_AAGGTTCGTAGTACCT           779      5.793743   HER2+
# CID3586_ACCAGTAGTTGTGGCC           514      1.383238   HER2+
# CID3586_ACCCACTAGATGTCGG           609      1.923077   HER2+
# ...
