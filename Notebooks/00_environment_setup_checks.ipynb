# %% [markdown]
# Environment setup
#
# All analysis in this project was conducted within a dedicated conda environment, scrna (Python 3.10). Activate this environment before installing packages or running any notebook in this project:
#
# conda activate scrna
#
# Installing packages into the base environment, or without activating scrna first, will target the wrong Python installation.

# %%
import scanpy
import anndata
import numpy
import pandas
import scipy
import matplotlib
import seaborn
import leidenalg
import harmonypy
import gseapy
import importlib.metadata

packages = ["scanpy", "anndata", "numpy", "pandas", "scipy",
            "matplotlib", "seaborn", "leidenalg", "harmonypy", "gseapy"]

for package in packages:
    print(f"{package}: {importlib.metadata.version(package)}")
# Out:
# scanpy: 1.11.5
# anndata: 0.11.4
# numpy: 2.2.6
# pandas: 2.3.3
# scipy: 1.15.2
# matplotlib: 3.10.9
# seaborn: 0.13.2
# leidenalg: 0.12.0
# harmonypy: 0.0.10
# gseapy: 1.2.1
