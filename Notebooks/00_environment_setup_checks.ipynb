# %%
import scanpy
import anndata
import numpy
import pandas
import scipy
import matplotlib
import seaborn
import leidenalg
import harmonypy
import gseapy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       7 import seaborn
#       8 import leidenalg
# ----> 9 import harmonypy
#      10 import gseapy
#
# ModuleNotFoundError: No module named 'harmonypy'

# %%
# !pip install harmonypy
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build harmonypy
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [18 lines of output]
#   *** scikit-build-core 0.12.2 using CMake 4.3.2 (wheel)
#   *** Configuring CMake...
#   loading initial cache file \tmp\harmonypy-build\cp313-cp313-win_amd64\CMakeInit.txt
#   -- Building for: NMake Makefiles
#   CMake Error at CMakeLists.txt:2 (project):
#     Running
#
#      'nmake' '-?'
#
#     failed with:
#
#      no such file or directory
#
#
#   CMake Error: CMAKE_CXX_COMPILER not set, after EnableLanguage
# ...

# %%
import harmonypy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import harmonypy
#
# ModuleNotFoundError: No module named 'harmonypy'

# %%
import scanpy
import anndata
import numpy
import pandas
import scipy
import matplotlib
import seaborn
import leidenalg

print("scanpy:", scanpy.__version__)
print("anndata:", anndata.__version__)
print("numpy:", numpy.__version__)
print("pandas:", pandas.__version__)
print("scipy:", scipy.__version__)
print("matplotlib:", matplotlib.__version__)
print("seaborn:", seaborn.__version__)
print("leidenalg:", leidenalg.__version__)
# Out:
# scanpy: 1.12.1
# anndata: 0.12.11
# numpy: 2.1.3
# pandas: 2.3.3
# scipy: 1.15.3
# matplotlib: 3.10.0
# seaborn: 0.13.2
# leidenalg: 0.11.0
# C:\Users\annam\AppData\Local\Temp\ipykernel_10660\4140025214.py:10: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   print("scanpy:", scanpy.__version__)
# C:\Users\annam\AppData\Local\Temp\ipykernel_10660\4140025214.py:11: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('anndata')` instead.
#   print("anndata:", anndata.__version__)

# %%
import jupyter
import black
import ruff
import gseapy

print("jupyter:", jupyter.__version__)
print("black:", black.__version__)
print("ruff:", ruff.__version__)
print("gseapy:", gseapy.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 import jupyter
#       2 import black
# ----> 3 import ruff
#       4 import gseapy
#       6 print("jupyter:", jupyter.__version__)
#
# ModuleNotFoundError: No module named 'ruff'

# %%
# !pip install ruff
# Out:
# ...
#    ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.9 MB 5.8 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.9 MB 5.1 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/11.9 MB 5.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.4/11.9 MB 5.0 MB/s eta 0:00:02
#    -------------- ------------------------- 4.2/11.9 MB 4.3 MB/s eta 0:00:02
#    -------------- ------------------------- 4.5/11.9 MB 4.1 MB/s eta 0:00:02
#    --------------- ------------------------ 4.7/11.9 MB 3.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.0/11.9 MB 3.3 MB/s eta 0:00:03
#    ------------------ --------------------- 5.5/11.9 MB 3.0 MB/s eta 0:00:03
#    ------------------- -------------------- 5.8/11.9 MB 2.9 MB/s eta 0:00:03
#    --------------------- ------------------ 6.3/11.9 MB 2.8 MB/s eta 0:00:03
# ...

# %%
import ruff
print(ruff.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import ruff
# ----> 2 print(ruff.__version__)
#
# AttributeError: module 'ruff' has no attribute '__version__'

# %%
import importlib.metadata

print(importlib.metadata.version("ruff"))
# Out:
# 0.15.13

# %%
import importlib.metadata

packages = [
    "jupyter",
    "gseapy",
    "black",
    "ruff",
    "pip",
    "harmonypy"
]

for package in packages:
    try:
        version = importlib.metadata.version(package)
        print(f"{package}: {version}")
    except Exception as e:
        print(f"{package}: NOT INSTALLED")
# Out:
# jupyter: 1.1.1
# gseapy: NOT INSTALLED
# black: 24.10.0
# ruff: 0.15.13
# pip: 25.1
# harmonypy: NOT INSTALLED

# %%
# !pip install gseapy

# %%
import gseapy
print(gseapy.__version__)
# Out:
# 1.2.1

# %%
# !pip install harmonypy
# Out:
# ...
#   Using cached harmonypy-2.0.0.tar.gz (35 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build harmonypy
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [19 lines of output]
#   *** scikit-build-core 0.12.2 using CMake 4.3.2 (wheel)
#   2026-05-18 20:57:53,351 - scikit_build_core - WARNING - Original src C:\Users\annam\AppData\Local\Temp\pip-install-m86dmy_5\harmonypy_50ffe6f394ec4920a3f8f1d984bf20c6 != C:\Users\annam\AppData\Local\Temp\pip-install-c77zkdcr\harmonypy_fbb5685cf84244d2a1c75414fc54335c, clearing cache
#   *** Configuring CMake...
# ...
